# %%
import numpy as np
a=np.array([2,5,7,8,9])
print(np.argmax(a))
# Out:
# 4

# %%
print(np.argmin(a))
# Out:
# 0

# %%
print(np.where(a>7))
# Out:
# (array([3, 4]),)

# %%
print(np.cumsum(a))
# Out:
# [ 2  7 14 22 31]

# %%
b=np.random.randint(1,10,15)
print(b)
# Out:
# [4 4 2 6 4 4 9 6 6 9 7 1 8 2 4]

# %%
a=np.array([6,7,8,9,10])
b=np.array([1,2,3,4,5])
print(np.corrcoef(a,b))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
a=np.array([24,45,67,90,34])
np.save("ps.npy",a)
print(np.load("ps.npy"))
# Out:
# [24 45 67 90 34]

# %%
a=np.array([6,7,8,9,10])
print(a[2:4])
# Out:
# [8 9]

# %%
print(a[2:])
# Out:
# [ 8  9 10]

# %%
print(a[:4])
# Out:
# [6 7 8 9]

# %%
print(a[-3:])
# Out:
# [ 8  9 10]

# %%
print(a[:-3])
# Out:
# [6 7]

# %%
Arr=np.array([[4,3,2,1],[6,7,5,3],[7,8,9,5]])
print(Arr[0:1,1:3])
# Out:
# [[3 2]]

# %%
print( Arr[: ,1:3])
# Out:
# [[3 2]
#  [7 5]
#  [8 9]]

# %%
print(Arr[:,::2])
# Out:
# [[4 2]
#  [6 5]
#  [7 9]]

# %%
import pandas as pd
a=pd.read_csv("sales_data.csv")
a
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
import pandas as pd
d={
    "Name":["lee","lee din cha","lee min ho"],
    "studentID":["ID0001","ID0002","ID0003"],
    "Age":[21,20,19]
    }
c=pd.DataFrame(d)
c
# Out:
#           Name studentID  Age
# 0          lee    ID0001   21
# 1  lee din cha    ID0002   20
# 2   lee min ho    ID0003   19

# %%
f=c.to_csv("studentID.csv")

# %%
d=pd.read_csv("studentID.csv")
d
# Out:
#    Unnamed: 0         Name studentID  Age
# 0           0          lee    ID0001   21
# 1           1  lee din cha    ID0002   20
# 2           2   lee min ho    ID0003   19

# %%
print(d["Name"],d["studentID"])
# Out:
# 0            lee
# 1    lee din cha
# 2     lee min ho
# Name: Name, dtype: object 0    ID0001
# 1    ID0002
# 2    ID0003
# Name: studentID, dtype: object

# %%
print(d.loc[0:1,["Name","Age"]])
# Out:
#           Name  Age
# 0          lee   21
# 1  lee din cha   20

# %%
print(d.loc[:,"Age"])
# Out:
# 0    21
# 1    20
# 2    19
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("sales_data.csv")
data
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
Product_Category=data["Product_Category"]
Sales_Amount=data["Region"]
print(Product_Category)
Region
# Out:
# 0        Furniture
# 1        Furniture
# 2             Food
# 3         Clothing
# 4      Electronics
#           ...
# 995           Food
# 996       Clothing
# 997       Clothing
# 998    Electronics
# 999           Food
# Name: Product_Category, Length: 1000, dtype: object
# 0      North
# 1       West
# 2      South
# 3      South
# 4       East
#        ...
# 995    North
# 996    North
# 997    South
# 998     West
# 999     East
# Name: Region, Length: 1000, dtype: object

# %%
import matplotlib.pyplot as plt
plt.plot(Product_Category,Region)
plt.title("Product_Category vs Region")
plt.xlabel("Product_Category")
plt.ylabel("Region")
plt.show()
